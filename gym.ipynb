# %%
import gym
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = gym.make('MsPacman-v0')
# Out:
# [2016-09-24 02:43:47,592] Making new env: MsPacman-v0

# %%
env.reset()
for _ in range(5):
    env.render()
    env.step(env.action_space.sample()) # take a random action

# %%
plt.imshow(env.reset());

# %%
env.action_space
# Out:
# Discrete(9)

# %%
observation, reward, done, info = env.step(1)

# %%
plt.imshow(observation);

# %%
reward, done, info
# Out:
# (0.0, False, {})

# %%
env = gym.make('CartPole-v0')
for i_episode in range(20):
    observation = env.reset()
    for t in range(1):
        env.render()
        print observation
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print "Episode finished after {} timesteps".format(t+1)
            break
# Out:
# [2016-09-24 02:17:07,701] Making new env: CartPole-v0
# [ 0.02936426  0.02128854  0.01843886 -0.03304338]
# [-0.03754672  0.00818225  0.04603432 -0.03845481]
# [ 0.00115258 -0.04141088  0.04886999 -0.00103437]
# [-0.03366538 -0.02340485  0.00038204 -0.01373476]
# [-0.01088796  0.04149323  0.028651   -0.02115795]
# [-0.02123134 -0.02154159 -0.01400001  0.03214375]
# [-0.03057465  0.01902302  0.02853889 -0.0005422 ]
# [-0.04346818  0.00971807 -0.01722891 -0.02992387]
# [-0.01397448  0.01076561 -0.00862828 -0.00147008]
# [-0.03225363 -0.01779533  0.03519167  0.03286886]
# [ 0.00761141 -0.0361154   0.00517645 -0.02692218]
# [ 0.01453045 -0.01681284 -0.04080424  0.04960448]
# [ 0.01453541  0.01380013 -0.04006113 -0.03594116]
# [-0.03712636  0.01957221 -0.02293589 -0.021915  ]
# [-0.03607825  0.02444662  0.04555289 -0.03631766]
# [ 0.00045774 -0.0050532  -0.02132174  0.04764906]
# [ 0.04786557  0.03789436  0.03007983  0.03062826]
# [-0.02458825 -0.01889766  0.01858028  0.03072008]
# [-0.00308515 -0.01105654  0.03066347  0.0347929 ]
# [ 0.02301256 -0.00307307 -0.01262732 -0.02581765]

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.observation_space
# Out:
# Box(4,)

# %%
from gym import spaces
spaces.Discrete(8).sample() # sample from set with 8 elements {0, 1, 2, ..., 7}
# Out:
# 6

# %%
env = gym.make('CartPole-v0')
env.monitor.start('cartpole-experiment-1')
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break

env.monitor.close()
# Out:
# [2016-09-24 02:48:39,020] Making new env: CartPole-v0
# ERROR: An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (83, 105))
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-5-1d8d1c500f1c> in <module>()
#       1 env = gym.make('CartPole-v0')
# ----> 2 env.monitor.start('cartpole-experiment-1')
#       3 for i_episode in range(20):
#       4     observation = env.reset()
#       5     for t in range(100):
#
# //anaconda/lib/python2.7/site-packages/gym/monitoring/monitor.pyc in start(self, directory, video_callable, force, resume, seed, write_upon_reset)
#     133                 raise error.Error('''Trying to write to monitor directory {} with existing monitor files: {}.
#     134
# --> 135  You should use a unique directory for each training run, or use 'force=True' to automatically clear previous monitor files.'''.format(directory, ', '.join(training_manifests[:5])))
#     136
#     137
#
# Error: Trying to write to monitor directory cartpole-experiment-1 with existing monitor files: cartpole-experiment-1/openaigym.manifest.0.80473.manifest.json.
#
#  You should use a unique directory for each training run, or use 'force=True' to automatically clear previous monitor files.

# %%
gym.envs.registry.all()
# Out:
# [EnvSpec(Asteroids-ramDeterministic-v2),
#  EnvSpec(Gopher-ramDeterministic-v2),
#  EnvSpec(RoadRunner-ramDeterministic-v2),
#  EnvSpec(DoubleDunk-ramDeterministic-v2),
#  EnvSpec(Phoenix-ram-v0),
#  EnvSpec(Robotank-ram-v0),
#  EnvSpec(Robotank-ram-v2),
#  EnvSpec(CartPole-v0),
#  EnvSpec(CartPole-v1),
#  EnvSpec(Gopher-ram-v2),
#  EnvSpec(SpaceInvaders-ram-v2),
#  EnvSpec(Gopher-ram-v0),
#  EnvSpec(Pooyan-ram-v0),
#  EnvSpec(Pooyan-ram-v2),
#  EnvSpec(CarRacing-v0),
#  EnvSpec(YarsRevenge-ramDeterministic-v2),
#  EnvSpec(SpaceInvaders-ram-v0),
#  EnvSpec(DoubleDunk-ram-v2),
#  EnvSpec(DoubleDunk-ram-v0),
#  EnvSpec(Centipede-v2),
#  EnvSpec(Centipede-v0),
#  EnvSpec(Pitfall-ramNoFrameskip-v2),
#  EnvSpec(VideoPinballDeterministic-v2),
#  EnvSpec(QbertNoFrameskip-v2),
#  EnvSpec(AmidarNoFrameskip-v2),
#  EnvSpec(Phoenix-ram-v2),
#  EnvSpec(HotterColder-v0),
#  EnvSpec(YarsRevenge-v0),
#  EnvSpec(Berzerk-ramNoFrameskip-v2),
#  EnvSpec(AirRaidDeterministic-v2),
#  EnvSpec(ChopperCommandDeterministic-v2),
#  EnvSpec(AirRaidNoFrameskip-v2),
#  EnvSpec(Asteroids-ram-v0),
#  EnvSpec(Asteroids-ram-v2),
#  EnvSpec(Atlantis-ramDeterministic-v2),
#  EnvSpec(SemisuperPendulumRandom-v0),
#  EnvSpec(KrullDeterministic-v2),
#  EnvSpec(MsPacman-ramNoFrameskip-v2),
#  EnvSpec(OffSwitchCartpoleProb-v0),
#  EnvSpec(Go19x19-v0),
#  EnvSpec(Solaris-ram-v0),
#  EnvSpec(Solaris-ram-v2),
#  EnvSpec(Gopher-v2),
#  EnvSpec(FishingDerbyNoFrameskip-v2),
#  EnvSpec(VentureDeterministic-v2),
#  EnvSpec(Qbert-v2),
#  EnvSpec(ReversedAddition-v0),
#  EnvSpec(Qbert-v0),
#  EnvSpec(Pitfall-v0),
#  EnvSpec(Pitfall-v2),
#  EnvSpec(RiverraidNoFrameskip-v2),
#  EnvSpec(BipedalWalkerHardcore-v2),
#  EnvSpec(Venture-ram-v2),
#  EnvSpec(Venture-ram-v0),
#  EnvSpec(Tennis-v0),
#  EnvSpec(Tennis-v2),
#  EnvSpec(MontezumaRevenge-ramNoFrameskip-v2),
#  EnvSpec(Go9x9-v0),
#  EnvSpec(MountainCarContinuous-v0),
#  EnvSpec(SemisuperPendulumNoise-v0),
#  EnvSpec(Reacher-v1),
#  EnvSpec(ChopperCommand-ramNoFrameskip-v2),
#  EnvSpec(Gravitar-ram-v0),
#  EnvSpec(Taxi-v1),
#  EnvSpec(Pong-v2),
#  EnvSpec(Pong-v0),
#  EnvSpec(UpNDownDeterministic-v2),
#  EnvSpec(Tutankham-ramDeterministic-v2),
#  EnvSpec(Enduro-v0),
#  EnvSpec(OneRoundNondeterministicReward-v0),
#  EnvSpec(Enduro-v2),
#  EnvSpec(Krull-ramNoFrameskip-v2),
#  EnvSpec(ElevatorAction-ramNoFrameskip-v2),
#  EnvSpec(TimePilot-ram-v0),
#  EnvSpec(Venture-ramNoFrameskip-v2),
#  EnvSpec(StarGunner-ramNoFrameskip-v2),
#  EnvSpec(BipedalWalker-v2),
#  EnvSpec(Breakout-ram-v0),
#  EnvSpec(Breakout-ram-v2),
#  EnvSpec(Bowling-v0),
#  EnvSpec(Bowling-v2),
#  EnvSpec(BattleZoneDeterministic-v2),
#  EnvSpec(PitfallNoFrameskip-v2),
#  EnvSpec(AirRaid-ramDeterministic-v2),
#  EnvSpec(Skiing-ram-v0),
#  EnvSpec(CentipedeNoFrameskip-v2),
#  EnvSpec(SpaceInvadersDeterministic-v2),
#  EnvSpec(Skiing-ram-v2),
#  EnvSpec(Freeway-ram-v2),
#  EnvSpec(Riverraid-ramNoFrameskip-v2),
#  EnvSpec(ChopperCommand-v2),
#  EnvSpec(ChopperCommand-v0),
#  EnvSpec(Pooyan-v0),
#  EnvSpec(Pooyan-v2),
#  EnvSpec(WizardOfWor-ramDeterministic-v2),
#  EnvSpec(PrivateEye-v2),
#  EnvSpec(BattleZoneNoFrameskip-v2),
#  EnvSpec(FrozenLake8x8-v0),
#  EnvSpec(Alien-ramNoFrameskip-v2),
#  EnvSpec(TutankhamDeterministic-v2),
#  EnvSpec(LunarLanderContinuous-v2),
#  EnvSpec(Phoenix-ramNoFrameskip-v2),
#  EnvSpec(Asterix-ram-v2),
#  EnvSpec(Asterix-ram-v0),
#  EnvSpec(Jamesbond-ramNoFrameskip-v2),
#  EnvSpec(JourneyEscape-v0),
#  EnvSpec(JourneyEscape-v2),
#  EnvSpec(AsteroidsDeterministic-v2),
#  EnvSpec(QbertDeterministic-v2),
#  EnvSpec(SpaceInvaders-ramDeterministic-v2),
#  EnvSpec(SolarisDeterministic-v2),
#  EnvSpec(YarsRevengeDeterministic-v2),
#  EnvSpec(TwoRoundDeterministicReward-v0),
#  EnvSpec(Bowling-ramNoFrameskip-v2),
#  EnvSpec(NameThisGame-ramNoFrameskip-v2),
#  EnvSpec(ElevatorAction-ramDeterministic-v2),
#  EnvSpec(TwoRoundNondeterministicReward-v0),
#  EnvSpec(TimePilotNoFrameskip-v2),
#  EnvSpec(Seaquest-v2),
#  EnvSpec(Pooyan-ramDeterministic-v2),
#  EnvSpec(Frostbite-ramNoFrameskip-v2),
#  EnvSpec(Seaquest-v0),
#  EnvSpec(PhoenixDeterministic-v2),
#  EnvSpec(CrazyClimber-ram-v0),
#  EnvSpec(MontezumaRevenge-ram-v0),
#  EnvSpec(CrazyClimber-ram-v2),
#  EnvSpec(MontezumaRevenge-ram-v2),
#  EnvSpec(StarGunner-ramDeterministic-v2),
#  EnvSpec(Centipede-ramNoFrameskip-v2),
#  EnvSpec(RoadRunner-ramNoFrameskip-v2),
#  EnvSpec(BeamRider-ramDeterministic-v2),
#  EnvSpec(KungFuMaster-v0),
#  EnvSpec(KungFuMaster-v2),
#  EnvSpec(BreakoutDeterministic-v2),
#  EnvSpec(Jamesbond-ramDeterministic-v2),
#  EnvSpec(Tennis-ramDeterministic-v2),
#  EnvSpec(IceHockey-v0),
#  EnvSpec(IceHockey-v2),
#  EnvSpec(Venture-ramDeterministic-v2),
#  EnvSpec(PongDeterministic-v2),
#  EnvSpec(RobotankDeterministic-v2),
#  EnvSpec(SeaquestNoFrameskip-v2),
#  EnvSpec(Pong-ramDeterministic-v2),
#  EnvSpec(SkiingNoFrameskip-v2),
#  EnvSpec(Berzerk-v2),
#  EnvSpec(Berzerk-v0),
#  EnvSpec(SemisuperPendulumDecay-v0),
#  EnvSpec(JourneyEscape-ramDeterministic-v2),
#  EnvSpec(MontezumaRevenge-v2),
#  EnvSpec(CrazyClimberDeterministic-v2),
#  EnvSpec(AirRaid-ram-v0),
#  EnvSpec(Carnival-ram-v2),
#  EnvSpec(AirRaid-ram-v2),
#  EnvSpec(Carnival-ram-v0),
#  EnvSpec(Zaxxon-v0),
#  EnvSpec(BeamRiderDeterministic-v2),
#  EnvSpec(YarsRevenge-ramNoFrameskip-v2),
#  EnvSpec(GopherNoFrameskip-v2),
#  EnvSpec(Phoenix-ramDeterministic-v2),
#  EnvSpec(Asteroids-v0),
#  EnvSpec(Hex9x9-v0),
#  EnvSpec(PooyanDeterministic-v2),
#  EnvSpec(Skiing-v0),
#  EnvSpec(Skiing-v2),
#  EnvSpec(Boxing-ramDeterministic-v2),
#  EnvSpec(PrivateEye-ram-v2),
#  EnvSpec(PrivateEye-ram-v0),
#  EnvSpec(Centipede-ramDeterministic-v2),
#  EnvSpec(JourneyEscapeNoFrameskip-v2),
#  EnvSpec(BattleZone-ramDeterministic-v2),
#  EnvSpec(NameThisGameNoFrameskip-v2),
#  EnvSpec(Seaquest-ram-v2),
#  EnvSpec(Seaquest-ram-v0),
#  EnvSpec(ElevatorAction-ram-v2),
#  EnvSpec(ElevatorAction-ram-v0),
#  EnvSpec(ChopperCommand-ramDeterministic-v2),
#  EnvSpec(Krull-ramDeterministic-v2),
#  EnvSpec(FishingDerby-ram-v0),
#  EnvSpec(Frostbite-ram-v2),
#  EnvSpec(Frostbite-ram-v0),
#  EnvSpec(BankHeistDeterministic-v2),
#  EnvSpec(Reverse-v0),
#  EnvSpec(SeaquestDeterministic-v2),
#  EnvSpec(JourneyEscape-ram-v0),
#  EnvSpec(JourneyEscape-ram-v2),
#  EnvSpec(BerzerkDeterministic-v2),
#  EnvSpec(VentureNoFrameskip-v2),
#  EnvSpec(Tennis-ramNoFrameskip-v2),
#  EnvSpec(UpNDown-ramDeterministic-v2),
#  EnvSpec(AssaultNoFrameskip-v2),
#  EnvSpec(Enduro-ramDeterministic-v2),
#  EnvSpec(PredictActionsCartpole-v0),
#  EnvSpec(Skiing-ramDeterministic-v2),
#  EnvSpec(Gopher-ramNoFrameskip-v2),
#  EnvSpec(IceHockey-ramDeterministic-v2),
#  EnvSpec(PhoenixNoFrameskip-v2),
#  EnvSpec(Humanoid-v1),
#  EnvSpec(NameThisGame-ram-v0),
#  EnvSpec(NameThisGame-ram-v2),
#  EnvSpec(Tutankham-ramNoFrameskip-v2),
#  EnvSpec(Skiing-ramNoFrameskip-v2),
#  EnvSpec(FishingDerby-ramNoFrameskip-v2),
#  EnvSpec(EnduroDeterministic-v2),
#  EnvSpec(Freeway-ram-v0),
#  EnvSpec(Assault-ramDeterministic-v2),
#  EnvSpec(Atlantis-ramNoFrameskip-v2),
#  EnvSpec(BreakoutNoFrameskip-v2),
#  EnvSpec(KungFuMaster-ram-v0),
#  EnvSpec(KungFuMaster-ram-v2),
#  EnvSpec(NameThisGame-ramDeterministic-v2),
#  EnvSpec(Frostbite-ramDeterministic-v2),
#  EnvSpec(BankHeist-ramNoFrameskip-v2),
#  EnvSpec(Ant-v1),
#  EnvSpec(Qbert-ramNoFrameskip-v2),
#  EnvSpec(Tennis-ram-v0),
#  EnvSpec(YarsRevenge-ram-v2),
#  EnvSpec(FrostbiteNoFrameskip-v2),
#  EnvSpec(FishingDerby-ram-v2),
#  EnvSpec(Enduro-ramNoFrameskip-v2),
#  EnvSpec(Tennis-ram-v2),
#  EnvSpec(BeamRiderNoFrameskip-v2),
#  EnvSpec(ReversedAddition3-v0),
#  EnvSpec(CentipedeDeterministic-v2),
#  EnvSpec(Gravitar-ramNoFrameskip-v2),
#  EnvSpec(Kangaroo-ram-v2),
#  EnvSpec(Kangaroo-ram-v0),
#  EnvSpec(Alien-ram-v2),
#  EnvSpec(Krull-v0),
#  EnvSpec(VideoPinball-ramNoFrameskip-v2),
#  EnvSpec(StarGunnerDeterministic-v2),
#  EnvSpec(PongNoFrameskip-v2),
#  EnvSpec(TimePilotDeterministic-v2),
#  EnvSpec(CNNClassifierTraining-v0),
#  EnvSpec(Boxing-ram-v0),
#  EnvSpec(Boxing-ram-v2),
#  EnvSpec(StarGunner-v0),
#  EnvSpec(StarGunner-v2),
#  EnvSpec(Jamesbond-v2),
#  EnvSpec(DemonAttackNoFrameskip-v2),
#  EnvSpec(Assault-ram-v2),
#  EnvSpec(Assault-ram-v0),
#  EnvSpec(Amidar-ram-v2),
#  EnvSpec(Amidar-ram-v0),
#  EnvSpec(ChopperCommandNoFrameskip-v2),
#  EnvSpec(Solaris-ramDeterministic-v2),
#  EnvSpec(ElevatorActionDeterministic-v2),
#  EnvSpec(Riverraid-ram-v0),
#  EnvSpec(Riverraid-ram-v2),
#  EnvSpec(Solaris-v0),
#  EnvSpec(Solaris-v2),
#  EnvSpec(BattleZone-v2),
#  EnvSpec(BattleZone-v0),
#  EnvSpec(MsPacmanNoFrameskip-v2),
#  EnvSpec(SolarisNoFrameskip-v2),
#  EnvSpec(VideoPinballNoFrameskip-v2),
#  EnvSpec(Breakout-ramDeterministic-v2),
#  EnvSpec(WizardOfWor-ram-v2),
#  EnvSpec(PrivateEye-ramDeterministic-v2),
#  EnvSpec(Gravitar-v0),
#  EnvSpec(Gravitar-v2),
#  EnvSpec(RoadRunner-ram-v2),
#  EnvSpec(RoadRunner-ram-v0),
#  EnvSpec(MsPacman-ram-v0),
#  EnvSpec(MsPacman-ram-v2),
#  EnvSpec(Riverraid-ramDeterministic-v2),
#  EnvSpec(VideoPinball-ram-v2),
#  EnvSpec(VideoPinball-ram-v0),
#  EnvSpec(OneRoundDeterministicReward-v0),
#  EnvSpec(WizardOfWorNoFrameskip-v2),
#  EnvSpec(FreewayNoFrameskip-v2),
#  EnvSpec(Asterix-ramNoFrameskip-v2),
#  EnvSpec(MontezumaRevengeNoFrameskip-v2),
#  EnvSpec(BankHeist-ramDeterministic-v2),
#  EnvSpec(InvertedDoublePendulum-v1),
#  EnvSpec(Asterix-v2),
#  EnvSpec(Asterix-v0),
#  EnvSpec(TimePilot-v2),
#  EnvSpec(TimePilot-v0),
#  EnvSpec(AsteroidsNoFrameskip-v2),
#  EnvSpec(WizardOfWor-ramNoFrameskip-v2),
#  EnvSpec(Pong-ramNoFrameskip-v2),
#  EnvSpec(ZaxxonDeterministic-v2),
#  EnvSpec(DemonAttack-ram-v2),
#  EnvSpec(ChopperCommand-ram-v2),
#  EnvSpec(ChopperCommand-ram-v0),
#  EnvSpec(SpaceInvaders-ramNoFrameskip-v2),
#  EnvSpec(BowlingDeterministic-v2),
#  EnvSpec(BankHeist-v0),
#  EnvSpec(UpNDown-v0),
#  EnvSpec(BankHeist-v2),
#  EnvSpec(TimePilot-ramDeterministic-v2),
#  EnvSpec(FishingDerby-ramDeterministic-v2),
#  EnvSpec(NChain-v0),
#  EnvSpec(PredictObsCartpole-v0),
#  EnvSpec(CrazyClimber-ramNoFrameskip-v2),
#  EnvSpec(MsPacman-ramDeterministic-v2),
#  EnvSpec(MsPacmanDeterministic-v2),
#  EnvSpec(CrazyClimber-v0),
#  EnvSpec(CrazyClimber-v2),
#  EnvSpec(Pitfall-ramDeterministic-v2),
#  EnvSpec(Enduro-ram-v0),
#  EnvSpec(Enduro-ram-v2),
#  EnvSpec(TennisNoFrameskip-v2),
#  EnvSpec(Breakout-ramNoFrameskip-v2),
#  EnvSpec(GravitarDeterministic-v2),
#  EnvSpec(Swimmer-v1),
#  EnvSpec(Alien-ram-v0),
#  EnvSpec(GravitarNoFrameskip-v2),
#  EnvSpec(AsterixDeterministic-v2),
#  EnvSpec(AlienDeterministic-v2),
#  EnvSpec(RoadRunnerDeterministic-v2),
#  EnvSpec(RepeatCopy-v0),
#  EnvSpec(KungFuMasterNoFrameskip-v2),
#  EnvSpec(Bowling-ramDeterministic-v2),
#  EnvSpec(FrostbiteDeterministic-v2),
#  EnvSpec(Carnival-ramDeterministic-v2),
#  EnvSpec(EnduroNoFrameskip-v2),
#  EnvSpec(Asteroids-ramNoFrameskip-v2),
#  EnvSpec(DemonAttackDeterministic-v2),
#  EnvSpec(JamesbondDeterministic-v2),
#  EnvSpec(DemonAttack-ram-v0),
#  EnvSpec(BankHeistNoFrameskip-v2),
#  EnvSpec(UpNDown-v2),
#  EnvSpec(Kangaroo-ramDeterministic-v2),
#  EnvSpec(RobotankNoFrameskip-v2),
#  EnvSpec(WizardOfWor-v2),
#  EnvSpec(WizardOfWor-v0),
#  EnvSpec(Hopper-v1),
#  EnvSpec(MontezumaRevenge-v0),
#  EnvSpec(BattleZone-ramNoFrameskip-v2),
#  EnvSpec(PrivateEye-v0),
#  EnvSpec(PrivateEyeDeterministic-v2),
#  EnvSpec(Pooyan-ramNoFrameskip-v2),
#  EnvSpec(ElevatorActionNoFrameskip-v2),
#  EnvSpec(FrozenLake-v0),
#  EnvSpec(Zaxxon-ramDeterministic-v2),
#  EnvSpec(JamesbondNoFrameskip-v2),
#  EnvSpec(HumanoidStandup-v1),
#  EnvSpec(KungFuMaster-ramDeterministic-v2),
#  EnvSpec(Amidar-v2),
#  EnvSpec(Amidar-v0),
#  EnvSpec(BerzerkNoFrameskip-v2),
#  EnvSpec(Asterix-ramDeterministic-v2),
#  EnvSpec(Amidar-ramNoFrameskip-v2),
#  EnvSpec(YarsRevenge-ram-v0),
#  EnvSpec(Gravitar-ramDeterministic-v2),
#  EnvSpec(BattleZone-ram-v2),
#  EnvSpec(BattleZone-ram-v0),
#  EnvSpec(IceHockey-ram-v0),
#  EnvSpec(IceHockey-ram-v2),
#  EnvSpec(MountainCar-v0),
#  EnvSpec(Qbert-ramDeterministic-v2),
#  EnvSpec(BeamRider-ramNoFrameskip-v2),
#  EnvSpec(Carnival-v2),
#  EnvSpec(Carnival-v0),
#  EnvSpec(IceHockeyNoFrameskip-v2),
#  EnvSpec(NameThisGameDeterministic-v2),
#  EnvSpec(DoubleDunk-ramNoFrameskip-v2),
#  EnvSpec(IceHockey-ramNoFrameskip-v2),
#  EnvSpec(YarsRevenge-v2),
#  EnvSpec(MsPacman-v0),
#  EnvSpec(MsPacman-v2),
#  EnvSpec(Solaris-ramNoFrameskip-v2),
#  EnvSpec(Walker2d-v1),
#  EnvSpec(Gopher-v0),
#  EnvSpec(Zaxxon-ram-v2),
#  EnvSpec(Zaxxon-ram-v0),
#  EnvSpec(DoubleDunkDeterministic-v2),
#  EnvSpec(PooyanNoFrameskip-v2),
#  EnvSpec(Seaquest-ramNoFrameskip-v2),
#  EnvSpec(FreewayDeterministic-v2),
#  EnvSpec(Blackjack-v0),
#  EnvSpec(TennisDeterministic-v2),
#  EnvSpec(Atlantis-v0),
#  EnvSpec(Atlantis-v2),
#  EnvSpec(GuessingGame-v0),
#  EnvSpec(Copy-v0),
#  EnvSpec(CrazyClimber-ramDeterministic-v2),
#  EnvSpec(Phoenix-v2),
#  EnvSpec(Phoenix-v0),
#  EnvSpec(StarGunner-ram-v0),
#  EnvSpec(CarnivalDeterministic-v2),
#  EnvSpec(StarGunner-ram-v2),
#  EnvSpec(Asteroids-v2),
#  EnvSpec(ZaxxonNoFrameskip-v2),
#  EnvSpec(Robotank-ramDeterministic-v2),
#  EnvSpec(IceHockeyDeterministic-v2),
#  EnvSpec(Centipede-ram-v2),
#  EnvSpec(Centipede-ram-v0),
#  EnvSpec(Assault-v2),
#  EnvSpec(Assault-v0),
#  EnvSpec(HalfCheetah-v1),
#  EnvSpec(Jamesbond-ram-v2),
#  EnvSpec(Jamesbond-ram-v0),
#  EnvSpec(WizardOfWorDeterministic-v2),
#  EnvSpec(DoubleDunk-v2),
#  EnvSpec(DoubleDunk-v0),
#  EnvSpec(Tutankham-v0),
#  EnvSpec(LunarLander-v2),
#  EnvSpec(Tutankham-v2),
#  EnvSpec(BeamRider-v2),
#  EnvSpec(BeamRider-v0),
#  EnvSpec(BoxingDeterministic-v2),
#  EnvSpec(CarnivalNoFrameskip-v2),
#  EnvSpec(Alien-v0),
#  EnvSpec(Alien-v2),
#  EnvSpec(Pitfall-ram-v0),
#  EnvSpec(Berzerk-ram-v2),
#  EnvSpec(Pitfall-ram-v2),
#  EnvSpec(Berzerk-ram-v0),
#  EnvSpec(Robotank-v0),
#  EnvSpec(AmidarDeterministic-v2),
#  EnvSpec(Robotank-v2),
#  EnvSpec(AssaultDeterministic-v2),
#  EnvSpec(Gravitar-ram-v2),
#  EnvSpec(Venture-v2),
#  EnvSpec(Frostbite-v2),
#  EnvSpec(Venture-v0),
#  EnvSpec(Frostbite-v0),
#  EnvSpec(Acrobot-v1),
#  EnvSpec(Boxing-v0),
#  EnvSpec(Boxing-v2),
#  EnvSpec(DemonAttack-v2),
#  EnvSpec(DemonAttack-v0),
#  EnvSpec(Freeway-v0),
#  EnvSpec(NameThisGame-v0),
#  EnvSpec(Freeway-v2),
#  EnvSpec(NameThisGame-v2),
#  EnvSpec(KungFuMasterDeterministic-v2),
#  EnvSpec(WizardOfWor-ram-v0),
#  EnvSpec(RoadRunnerNoFrameskip-v2),
#  EnvSpec(Bowling-ram-v0),
#  EnvSpec(Bowling-ram-v2),
#  EnvSpec(Krull-ram-v2),
#  EnvSpec(Seaquest-ramDeterministic-v2),
#  EnvSpec(Krull-ram-v0),
#  EnvSpec(TimePilot-ramNoFrameskip-v2),
#  EnvSpec(BowlingNoFrameskip-v2),
#  EnvSpec(UpNDown-ramNoFrameskip-v2),
#  EnvSpec(Assault-ramNoFrameskip-v2),
#  EnvSpec(PrivateEye-ramNoFrameskip-v2),
#  EnvSpec(RoadRunner-v2),
#  EnvSpec(KungFuMaster-ramNoFrameskip-v2),
#  EnvSpec(AirRaid-v0),
#  EnvSpec(BankHeist-ram-v0),
#  EnvSpec(BankHeist-ram-v2),
#  EnvSpec(RoadRunner-v0),
#  EnvSpec(YarsRevengeNoFrameskip-v2),
#  EnvSpec(ElevatorAction-v2),
#  EnvSpec(ElevatorAction-v0),
#  EnvSpec(DemonAttack-ramDeterministic-v2),
#  EnvSpec(Carnival-ramNoFrameskip-v2),
#  EnvSpec(FishingDerby-v0),
#  EnvSpec(FishingDerby-v2),
#  EnvSpec(MontezumaRevengeDeterministic-v2),
#  EnvSpec(DoubleDunkNoFrameskip-v2),
#  EnvSpec(AsterixNoFrameskip-v2),
#  EnvSpec(UpNDown-ram-v2),
#  EnvSpec(Amidar-ramDeterministic-v2),
#  EnvSpec(Pong-ram-v2),
#  EnvSpec(Pong-ram-v0),
#  EnvSpec(Pendulum-v0),
#  EnvSpec(JourneyEscapeDeterministic-v2),
#  EnvSpec(Freeway-ramDeterministic-v2),
#  EnvSpec(Breakout-v0),
#  EnvSpec(Breakout-v2),
#  EnvSpec(Zaxxon-v2),
#  EnvSpec(BeamRider-ram-v2),
#  EnvSpec(InvertedPendulum-v1),
#  EnvSpec(BeamRider-ram-v0),
#  EnvSpec(VideoPinball-v2),
#  EnvSpec(VideoPinball-v0),
#  EnvSpec(Riverraid-v0),
#  EnvSpec(PrivateEyeNoFrameskip-v2),
#  EnvSpec(AtlantisDeterministic-v2),
#  EnvSpec(Berzerk-ramDeterministic-v2),
#  EnvSpec(AirRaid-ramNoFrameskip-v2),
#  EnvSpec(Roulette-v0),
#  EnvSpec(Atlantis-ram-v0),
#  EnvSpec(Atlantis-ram-v2),
#  EnvSpec(Freeway-ramNoFrameskip-v2),
#  EnvSpec(Boxing-ramNoFrameskip-v2),
#  EnvSpec(PitfallDeterministic-v2),
#  EnvSpec(Jamesbond-v0),
#  EnvSpec(Zaxxon-ramNoFrameskip-v2),
#  EnvSpec(SpaceInvaders-v2),
#  EnvSpec(UpNDownNoFrameskip-v2),
#  EnvSpec(CrazyClimberNoFrameskip-v2),
#  EnvSpec(AtlantisNoFrameskip-v2),
#  EnvSpec(KangarooNoFrameskip-v2),
#  EnvSpec(SpaceInvaders-v0),
#  EnvSpec(StarGunnerNoFrameskip-v2),
#  EnvSpec(Kangaroo-ramNoFrameskip-v2),
#  EnvSpec(SpaceInvadersNoFrameskip-v2),
#  EnvSpec(Qbert-ram-v2),
#  EnvSpec(DuplicatedInput-v0),
#  EnvSpec(Robotank-ramNoFrameskip-v2),
#  EnvSpec(TutankhamNoFrameskip-v2),
#  EnvSpec(DemonAttack-ramNoFrameskip-v2),
#  EnvSpec(ConvergenceControl-v0),
#  EnvSpec(GopherDeterministic-v2),
#  EnvSpec(Alien-ramDeterministic-v2),
#  EnvSpec(Qbert-ram-v0),
#  EnvSpec(FishingDerbyDeterministic-v2),
#  EnvSpec(VideoPinball-ramDeterministic-v2),
#  EnvSpec(TimePilot-ram-v2),
#  EnvSpec(Tutankham-ram-v2),
#  EnvSpec(KangarooDeterministic-v2),
#  EnvSpec(AirRaid-v2),
#  EnvSpec(Krull-v2),
#  EnvSpec(JourneyEscape-ramNoFrameskip-v2),
#  EnvSpec(KrullNoFrameskip-v2),
#  EnvSpec(Riverraid-v2),
#  EnvSpec(MontezumaRevenge-ramDeterministic-v2),
#  EnvSpec(RiverraidDeterministic-v2),
#  EnvSpec(AlienNoFrameskip-v2),
#  EnvSpec(Tutankham-ram-v0),
#  EnvSpec(BoxingNoFrameskip-v2),
#  EnvSpec(SkiingDeterministic-v2),
#  EnvSpec(OffSwitchCartpole-v0),
#  EnvSpec(UpNDown-ram-v0),
#  EnvSpec(Kangaroo-v2),
#  EnvSpec(Kangaroo-v0)]

# %%
gym.make('DoomBasic-v0')
